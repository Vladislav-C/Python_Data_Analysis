# %%
import matplotlib.pyplot as plt
import pandas as pd
import ast

df = pd.read_csv("Data/data_jobs.csv")
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'], errors='coerce')
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %% [markdown]
# ## Countries and Job Title's Median Salary

# %%
df_job_country_salary = df.pivot_table(
    values='salary_year_avg',        # The data to aggregate
    index='job_country',             # Rows (index of pivot table)
    columns='job_title_short',       # Columns (pivot table headers)
    aggfunc='median'                 # Aggregation function
)

df_job_country_salary
# Out:
# job_title_short  Business Analyst  Cloud Engineer  Data Analyst  \
# job_country
# Albania                       NaN             NaN      49950.00
# Algeria                       NaN             NaN      44100.00
# Argentina                 71100.0        197500.0      92771.75
# Armenia                       NaN             NaN     100500.00
# Australia                 70000.0        110000.0     109500.00
# ...                           ...             ...           ...
# Uruguay                       NaN             NaN     100500.00
# Uzbekistan                    NaN             NaN           NaN
# Vietnam                   79200.0             NaN      75550.00
# Zambia                        NaN             NaN           NaN
# Zimbabwe                      NaN             NaN      63000.00
#
# job_title_short  Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_country
# Albania                    NaN        69981.25                        NaN
# Algeria                45000.0             NaN                        NaN
# Argentina              96773.0        71000.00                   101029.0
# Armenia                48750.0             NaN                    87021.0
# Australia             106712.5       139216.00                   101029.0
# ...                        ...             ...                        ...
# Uruguay                    NaN             NaN                    50000.0
# Uzbekistan                 NaN        30750.00                        NaN
# Vietnam                96773.0        70000.00                    57600.0
# Zambia                     NaN        90670.00                        NaN
# Zimbabwe                   NaN        69085.00                        NaN
#
# job_title_short  Senior Data Analyst  Senior Data Engineer  \
# job_country
# Albania                          NaN                   NaN
# Algeria                          NaN                   NaN
# Argentina                        NaN              147500.0
# Armenia                          NaN                   NaN
# Australia                    50640.0              147500.0
# ...                              ...                   ...
# Uruguay                          NaN                   NaN
# Uzbekistan                       NaN                   NaN
# Vietnam                     105837.5              147500.0
# Zambia                           NaN                   NaN
# Zimbabwe                         NaN                   NaN
#
# job_title_short  Senior Data Scientist  Software Engineer
# job_country
# Albania                       157500.0                NaN
# Algeria                            NaN                NaN
# Argentina                          NaN           174500.0
# Armenia                            NaN                NaN
# Australia                     157500.0           118350.0
# ...                                ...                ...
# Uruguay                        57500.0                NaN
# Uzbekistan                         NaN                NaN
# Vietnam                        79200.0            53600.0
# Zambia                             NaN                NaN
# Zimbabwe                           NaN                NaN
#
# [108 rows x 10 columns]

# %%
# make a list of top 6 countries
top_countries = df['job_country'].value_counts().head(6).index

# filter df_job_country_salary for top 6 countries
df_job_country_salary = df_job_country_salary.loc[top_countries]

# filter df_job_country_salary for list of 3 job titles
job_titles = ['Data Analyst', 'Data Engineer', 'Data Scientist'] # 'Senior Data Analyst', 'Senior Data Engineer', 'Senior Data Scientist']
df_job_country_salary = df_job_country_salary[job_titles]

df_job_country_salary.plot(kind='bar')
plt.ylabel('Median Salary ($USD)')
plt.xlabel('')
plt.title('Median Salary by Country and Job Title')  
plt.xticks(rotation=45, ha='right')
plt.legend()
plt.show()

# %% [markdown]
# ## Monthly Job Postings for Top Data Jobs

# %%
df_US = df[df['job_country'] == 'United States'].copy()

# %%
df_US['job_posted_month'] = df_US['job_posted_date'].dt.strftime('%B')
df_US.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 5         Data Engineer                                  GCP Data Engineer
# 6  Senior Data Engineer                  Senior Data Engineer  - GCP Cloud
# 9        Data Scientist                                  Data Scientist II
#
#       job_location            job_via         job_schedule_type  \
# 0    Watertown, CT    via Work Nearby                 Full-time
# 3  San Antonio, TX  via Diversity.com                 Full-time
# 5         Anywhere   via ZipRecruiter  Contractor and Temp work
# 6     Dearborn, MI       via LinkedIn                 Full-time
# 9         Anywhere   via ZipRecruiter                 Full-time
#
#    job_work_from_home          search_location     job_posted_date  \
# 0               False     Texas, United States 2023-06-16 13:44:15
# 3               False     Texas, United States 2023-07-04 13:01:41
# 5                True                  Georgia 2023-11-07 14:01:59
# 6               False   Florida, United States 2023-03-27 13:18:18
# 9                True  New York, United States 2023-04-23 13:02:57
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                  False                 False  United States         NaN
# 3                   True                 False  United States         NaN
# 5                  False                 False  United States         NaN
# 6                  False                 False  United States         NaN
# 9                  False                 False  United States         NaN
#
#    salary_year_avg  salary_hour_avg                   company_name  \
# 0              NaN              NaN           Boehringer Ingelheim
# 3              NaN              NaN   Southwest Research Institute
# 5              NaN              NaN                smart folks inc
# 6              NaN              NaN  Miracle Software Systems, Inc
# 9              NaN              NaN     Radwell International, LLC
#
#                                           job_skills  \
# 0                                                NaN
# 3  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 5                           ['python', 'sql', 'gcp']
# 6  ['sql', 'python', 'java', 'sql server', 'gcp',...
# 9  ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
#
#                                      job_type_skills job_posted_month
# 0                                                NaN             June
# 3  {'cloud': ['aws'], 'libraries': ['tensorflow',...             July
# 5  {'cloud': ['gcp'], 'programming': ['python', '...         November
# 6  {'cloud': ['gcp', 'bigquery'], 'databases': ['...            March
# 9  {'analyst_tools': ['excel'], 'cloud': ['azure'...            April

# %%
df_US_pt = df_US.pivot_table(index='job_posted_month', columns='job_title_short', aggfunc='size')
df_US_pt
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# April                          565              40          6049
# August                         903              39          6634
# December                       648              40          3979
# February                       447              24          6124
# January                        527              36          8494
# July                           581              39          5201
# June                           446              32          5683
# March                          438              19          6218
# May                            279              20          4993
# November                       719              36          4531
# October                        932              48          5271
# September                      897              50          4639
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# April                      2801            4867                         51
# August                     3269            6318                         68
# December                   2641            3472                        119
# February                   3060            4956                         56
# January                    2655            6915                         60
# July                       2570            4876                         65
# June                       2893            4645                         48
# March                      3183            4779                         59
# May                        2976            4377                         49
# November                   2793            4175                        132
# October                    3015            4882                        101
# September                  3224            4568                        113
#
# job_title_short   Senior Data Analyst  Senior Data Engineer  \
# job_posted_month
# April                            1025                   781
# August                           1186                   903
# December                          601                   689
# February                         1258                   878
# January                          1544                   773
# July                              883                   747
# June                             1009                   812
# March                            1114                   829
# May                               839                   746
# November                          656                   684
# October                           871                   672
# September                         805                   775
#
# job_title_short   Senior Data Scientist  Software Engineer
# job_posted_month
# April                               991                112
# August                             1515                194
# December                            752                212
# February                           1127                 90
# January                            1552                114
# July                               1095                153
# June                               1033                 93
# March                              1150                115
# May                                 914                 90
# November                            816                194
# October                             987                219
# September                          1014                228

# %%
df_US_pt.reset_index(inplace=True)
df_US_pt
# Out:
# job_title_short job_posted_month  Business Analyst  Cloud Engineer  \
# 0                          April               565              40
# 1                         August               903              39
# 2                       December               648              40
# 3                       February               447              24
# 4                        January               527              36
# 5                           July               581              39
# 6                           June               446              32
# 7                          March               438              19
# 8                            May               279              20
# 9                       November               719              36
# 10                       October               932              48
# 11                     September               897              50
#
# job_title_short  Data Analyst  Data Engineer  Data Scientist  \
# 0                        6049           2801            4867
# 1                        6634           3269            6318
# 2                        3979           2641            3472
# 3                        6124           3060            4956
# 4                        8494           2655            6915
# 5                        5201           2570            4876
# 6                        5683           2893            4645
# 7                        6218           3183            4779
# 8                        4993           2976            4377
# 9                        4531           2793            4175
# 10                       5271           3015            4882
# 11                       4639           3224            4568
#
# job_title_short  Machine Learning Engineer  Senior Data Analyst  \
# 0                                       51                 1025
# 1                                       68                 1186
# 2                                      119                  601
# 3                                       56                 1258
# 4                                       60                 1544
# 5                                       65                  883
# 6                                       48                 1009
# 7                                       59                 1114
# 8                                       49                  839
# 9                                      132                  656
# 10                                     101                  871
# 11                                     113                  805
#
# job_title_short  Senior Data Engineer  Senior Data Scientist  \
# 0                                 781                    991
# 1                                 903                   1515
# 2                                 689                    752
# 3                                 878                   1127
# 4                                 773                   1552
# 5                                 747                   1095
# 6                                 812                   1033
# 7                                 829                   1150
# 8                                 746                    914
# 9                                 684                    816
# 10                                672                    987
# 11                                775                   1014
#
# job_title_short  Software Engineer
# 0                              112
# 1                              194
# 2                              212
# 3                               90
# 4                              114
# 5                              153
# 6                               93
# 7                              115
# 8                               90
# 9                              194
# 10                             219
# 11                             228

# %%
df_US_pt['month_no'] = pd.to_datetime(df_US_pt['job_posted_month'], format='%B').dt.month
df_US_pt.sort_values('month_no', inplace=True)
df_US_pt
# Out:
# job_title_short job_posted_month  Business Analyst  Cloud Engineer  \
# 4                        January               527              36
# 3                       February               447              24
# 7                          March               438              19
# 0                          April               565              40
# 8                            May               279              20
# 6                           June               446              32
# 5                           July               581              39
# 1                         August               903              39
# 11                     September               897              50
# 10                       October               932              48
# 9                       November               719              36
# 2                       December               648              40
#
# job_title_short  Data Analyst  Data Engineer  Data Scientist  \
# 4                        8494           2655            6915
# 3                        6124           3060            4956
# 7                        6218           3183            4779
# 0                        6049           2801            4867
# 8                        4993           2976            4377
# 6                        5683           2893            4645
# 5                        5201           2570            4876
# 1                        6634           3269            6318
# 11                       4639           3224            4568
# 10                       5271           3015            4882
# 9                        4531           2793            4175
# 2                        3979           2641            3472
#
# job_title_short  Machine Learning Engineer  Senior Data Analyst  \
# 4                                       60                 1544
# 3                                       56                 1258
# 7                                       59                 1114
# 0                                       51                 1025
# 8                                       49                  839
# 6                                       48                 1009
# 5                                       65                  883
# 1                                       68                 1186
# 11                                     113                  805
# 10                                     101                  871
# 9                                      132                  656
# 2                                      119                  601
#
# job_title_short  Senior Data Engineer  Senior Data Scientist  \
# 4                                 773                   1552
# 3                                 878                   1127
# 7                                 829                   1150
# 0                                 781                    991
# 8                                 746                    914
# 6                                 812                   1033
# 5                                 747                   1095
# 1                                 903                   1515
# 11                                775                   1014
# 10                                672                    987
# 9                                 684                    816
# 2                                 689                    752
#
# job_title_short  Software Engineer  month_no
# 4                              114         1
# 3                               90         2
# 7                              115         3
# 0                              112         4
# 8                               90         5
# 6                               93         6
# 5                              153         7
# 1                              194         8
# 11                             228         9
# 10                             219        10
# 9                              194        11
# 2                              212        12

# %%
df_US_pt.set_index('job_posted_month', inplace=True)
df_US_pt.drop('month_no', axis=1, inplace=True)
df_US_pt
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        527              36          8494
# February                       447              24          6124
# March                          438              19          6218
# April                          565              40          6049
# May                            279              20          4993
# June                           446              32          5683
# July                           581              39          5201
# August                         903              39          6634
# September                      897              50          4639
# October                        932              48          5271
# November                       719              36          4531
# December                       648              40          3979
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# January                    2655            6915                         60
# February                   3060            4956                         56
# March                      3183            4779                         59
# April                      2801            4867                         51
# May                        2976            4377                         49
# June                       2893            4645                         48
# July                       2570            4876                         65
# August                     3269            6318                         68
# September                  3224            4568                        113
# October                    3015            4882                        101
# November                   2793            4175                        132
# December                   2641            3472                        119
#
# job_title_short   Senior Data Analyst  Senior Data Engineer  \
# job_posted_month
# January                          1544                   773
# February                         1258                   878
# March                            1114                   829
# April                            1025                   781
# May                               839                   746
# June                             1009                   812
# July                              883                   747
# August                           1186                   903
# September                         805                   775
# October                           871                   672
# November                          656                   684
# December                          601                   689
#
# job_title_short   Senior Data Scientist  Software Engineer
# job_posted_month
# January                            1552                114
# February                           1127                 90
# March                              1150                115
# April                               991                112
# May                                 914                 90
# June                               1033                 93
# July                               1095                153
# August                             1515                194
# September                          1014                228
# October                             987                219
# November                            816                194
# December                            752                212

# %%
top_3 = df_US['job_title_short'].value_counts().head(3)
top_3 = top_3.index.tolist()

# %%
df_US_pt[top_3].plot(kind='line')
plt.title('Monthly Job Postings for Top Data Jobs in the US')
plt.xlabel('2023')
plt.ylabel('Job Count')
plt.legend()
plt.show()

# %% [markdown]
# ## Trending Skills

# %%
df_DA = df[df['job_title_short'] == 'Data Analyst'].copy()

# %%
df_DA['job_posted_month_no'] = df_DA['job_posted_date'].dt.month

# %%
df_DA_explode = df_DA.explode('job_skills')

# %%
df_DA_pt = df_DA_explode.pivot_table(index='job_posted_month_no', columns='job_skills', aggfunc='size', fill_value=0)
df_DA_pt
# Out:
# job_skills           airflow  airtable  alteryx  angular  angular.js  ansible  \
# job_posted_month_no
# 1                        197        17      551       63           2       20
# 2                        169         2      448       49           0       14
# 3                        181         4      442       34           0       23
# 4                        155         4      413       22           0       11
# 5                        128         8      310       30           0       19
# 6                        164        14      393       29           0       14
# 7                        207         4      366       15           0        8
# 8                        197         3      413       21           0       12
# 9                        118         4      317       21           0       14
# 10                       173        11      350       40           0       19
# 11                       169         7      293       24           0       19
# 12                       144        10      274       28           0       13
#
# job_skills           apl  arch  asana  asp.net  ...  webex  windows  wire  \
# job_posted_month_no                             ...
# 1                      2     1     29       34  ...     17      228     6
# 2                      1     4     27       13  ...      9      202     6
# 3                      6     1     17       13  ...      8      194     8
# 4                      8     9      9       15  ...      9      185    14
# 5                      9     2      8       21  ...     11      122     3
# 6                      9     4     16       16  ...      8      157    14
# 7                      5     8     19       12  ...      5      161    11
# 8                     10     3     13       12  ...      9      184    11
# 9                      3    10     12       10  ...      4      150     8
# 10                     0     8     11       14  ...      4      156     8
# 11                     0     5      4       12  ...      4      144     4
# 12                     0     8     11        9  ...      6      139     8
#
# job_skills           word  workfront  wrike  wsl  xamarin  yarn  zoom
# job_posted_month_no
# 1                    1778          0     11    6        0     9    95
# 2                    1235          4      2    5        0     4    41
# 3                    1203          1      1    3        1     5    45
# 4                    1177          8      2    1        0     6    26
# 5                     957          3      4    0        0     7    18
# 6                    1237          6      6    0        0    11    34
# 7                    1069          0      3    0        0     6    38
# 8                    1298          0      1    0        0    11    41
# 9                     945          0      1    0        0     5    25
# 10                    990          5      2    0        1     4    39
# 11                    887          1      1    1        0     6    26
# 12                    786          3      5    0        0     2    37
#
# [12 rows x 235 columns]

# %%
df_DA_pt.loc['Total'] = df_DA_pt.sum()
df_DA_pt
# Out:
# job_skills           airflow  airtable  alteryx  angular  angular.js  ansible  \
# job_posted_month_no
# 1                        197        17      551       63           2       20
# 2                        169         2      448       49           0       14
# 3                        181         4      442       34           0       23
# 4                        155         4      413       22           0       11
# 5                        128         8      310       30           0       19
# 6                        164        14      393       29           0       14
# 7                        207         4      366       15           0        8
# 8                        197         3      413       21           0       12
# 9                        118         4      317       21           0       14
# 10                       173        11      350       40           0       19
# 11                       169         7      293       24           0       19
# 12                       144        10      274       28           0       13
# Total                   2002        88     4570      376           2      186
#
# job_skills           apl  arch  asana  asp.net  ...  webex  windows  wire  \
# job_posted_month_no                             ...
# 1                      2     1     29       34  ...     17      228     6
# 2                      1     4     27       13  ...      9      202     6
# 3                      6     1     17       13  ...      8      194     8
# 4                      8     9      9       15  ...      9      185    14
# 5                      9     2      8       21  ...     11      122     3
# 6                      9     4     16       16  ...      8      157    14
# 7                      5     8     19       12  ...      5      161    11
# 8                     10     3     13       12  ...      9      184    11
# 9                      3    10     12       10  ...      4      150     8
# 10                     0     8     11       14  ...      4      156     8
# 11                     0     5      4       12  ...      4      144     4
# 12                     0     8     11        9  ...      6      139     8
# Total                 53    63    176      181  ...     94     2022   101
#
# job_skills            word  workfront  wrike  wsl  xamarin  yarn  zoom
# job_posted_month_no
# 1                     1778          0     11    6        0     9    95
# 2                     1235          4      2    5        0     4    41
# 3                     1203          1      1    3        1     5    45
# 4                     1177          8      2    1        0     6    26
# 5                      957          3      4    0        0     7    18
# 6                     1237          6      6    0        0    11    34
# 7                     1069          0      3    0        0     6    38
# 8                     1298          0      1    0        0    11    41
# 9                      945          0      1    0        0     5    25
# 10                     990          5      2    0        1     4    39
# 11                     887          1      1    1        0     6    26
# 12                     786          3      5    0        0     2    37
# Total                13562         31     39   16        2    76   465
#
# [13 rows x 235 columns]

# %%
df_DA_pt = df_DA_pt[df_DA_pt.loc['Total'].sort_values(ascending=False).index]
df_DA_pt = df_DA_pt.drop('Total')
df_DA_pt
# Out:
# job_skills             sql  excel  python  tableau  power bi     r   sas  \
# job_posted_month_no
# 1                    11336   8170    6606     5596      4285  3607  3830
# 2                     7947   5772    4751     3936      3307  2576  2634
# 3                     7868   5675    4741     4051      3176  2650  2554
# 4                     7553   5496    4557     3776      3106  2399  2598
# 5                     6617   4773    4070     3245      2695  2093  1940
# 6                     7584   5724    4707     3812      3275  2442  2174
# 7                     7687   5513    4831     3928      3350  2444  2118
# 8                     8823   6482    5576     4533      3859  2975  2560
# 9                     6829   4886    4229     3446      3118  2146  1880
# 10                    7474   5217    4693     3709      3340  2380  2114
# 11                    6652   4776    4233     3284      3012  2159  1738
# 12                    6058   4376    4196     3139      2857  2125  1858
#
# job_skills           powerpoint  word   sap  ...  angular.js  xamarin  gtx  \
# job_posted_month_no                          ...
# 1                          1880  1778  1251  ...           2        0    0
# 2                          1291  1235   954  ...           0        0    0
# 3                          1266  1203   892  ...           0        1    0
# 4                          1190  1177   947  ...           0        0    0
# 5                           979   957   851  ...           0        0    0
# 6                          1173  1237   987  ...           0        0    0
# 7                          1096  1069   996  ...           0        0    1
# 8                          1332  1298  1117  ...           0        0    0
# 9                           944   945   852  ...           0        0    0
# 10                          955   990   872  ...           0        1    0
# 11                          894   887   808  ...           0        0    0
# 12                          822   786   753  ...           0        0    0
#
# job_skills           nuxt.js  ovh  esquisse  suse  capacitor  chainer  \
# job_posted_month_no
# 1                          1    0         0     0          1        0
# 2                          0    0         0     0          0        0
# 3                          0    0         0     1          0        0
# 4                          0    1         0     0          0        0
# 5                          0    0         0     0          0        0
# 6                          0    0         0     0          0        0
# 7                          0    0         0     0          0        0
# 8                          0    0         0     0          0        0
# 9                          0    0         0     0          0        0
# 10                         0    0         0     0          0        0
# 11                         0    0         1     0          0        0
# 12                         0    0         0     0          0        1
#
# job_skills           msaccess
# job_posted_month_no
# 1                           0
# 2                           0
# 3                           0
# 4                           0
# 5                           1
# 6                           0
# 7                           0
# 8                           0
# 9                           0
# 10                          0
# 11                          0
# 12                          0
#
# [12 rows x 235 columns]

# %%
df_DA_pt = df_DA_pt.reset_index()
df_DA_pt['job_posted_month'] = df_DA_pt['job_posted_month_no'].apply(lambda x: pd.to_datetime(x, format='%m').strftime('%b'))
df_DA_pt = df_DA_pt.set_index('job_posted_month')
df_DA_pt = df_DA_pt.drop(columns='job_posted_month_no')

df_DA_pt
# Out:
# job_skills          sql  excel  python  tableau  power bi     r   sas  \
# job_posted_month
# Jan               11336   8170    6606     5596      4285  3607  3830
# Feb                7947   5772    4751     3936      3307  2576  2634
# Mar                7868   5675    4741     4051      3176  2650  2554
# Apr                7553   5496    4557     3776      3106  2399  2598
# May                6617   4773    4070     3245      2695  2093  1940
# Jun                7584   5724    4707     3812      3275  2442  2174
# Jul                7687   5513    4831     3928      3350  2444  2118
# Aug                8823   6482    5576     4533      3859  2975  2560
# Sep                6829   4886    4229     3446      3118  2146  1880
# Oct                7474   5217    4693     3709      3340  2380  2114
# Nov                6652   4776    4233     3284      3012  2159  1738
# Dec                6058   4376    4196     3139      2857  2125  1858
#
# job_skills        powerpoint  word   sap  ...  angular.js  xamarin  gtx  \
# job_posted_month                          ...
# Jan                     1880  1778  1251  ...           2        0    0
# Feb                     1291  1235   954  ...           0        0    0
# Mar                     1266  1203   892  ...           0        1    0
# Apr                     1190  1177   947  ...           0        0    0
# May                      979   957   851  ...           0        0    0
# Jun                     1173  1237   987  ...           0        0    0
# Jul                     1096  1069   996  ...           0        0    1
# Aug                     1332  1298  1117  ...           0        0    0
# Sep                      944   945   852  ...           0        0    0
# Oct                      955   990   872  ...           0        1    0
# Nov                      894   887   808  ...           0        0    0
# Dec                      822   786   753  ...           0        0    0
#
# job_skills        nuxt.js  ovh  esquisse  suse  capacitor  chainer  msaccess
# job_posted_month
# Jan                     1    0         0     0          1        0         0
# Feb                     0    0         0     0          0        0         0
# Mar                     0    0         0     1          0        0         0
# Apr                     0    1         0     0          0        0         0
# May                     0    0         0     0          0        0         1
# Jun                     0    0         0     0          0        0         0
# Jul                     0    0         0     0          0        0         0
# Aug                     0    0         0     0          0        0         0
# Sep                     0    0         0     0          0        0         0
# Oct                     0    0         0     0          0        0         0
# Nov                     0    0         1     0          0        0         0
# Dec                     0    0         0     0          0        1         0
#
# [12 rows x 235 columns]

# %%
df_DA_pt.iloc[:, :5].plot(kind='line')

plt.title('Top 5 Skills for Data Analysts per Month')
plt.ylabel('Count')
plt.xlabel('')
plt.show()

# %%
df_DA_pt.iloc[:, :5].plot(
    kind='line',
    linewidth=4,
    linestyle=':',
    colormap='viridis',
    marker='o',
    markersize=5,
    figsize=(10, 5)
)

plt.title('Top 5 Skills for Data Analysts per Month')
plt.ylabel('Count')
plt.xlabel('')
plt.show()

# %% [markdown]
# ## Counts of Top Skills in Job Postings

# %%
df_skills = df.copy()
df_skills = df_skills.explode('job_skills')
skills_count = df_skills.groupby(['job_skills', 'job_title_short']).size()
df_skills_count = skills_count.sort_values(ascending=False).reset_index(name='skill_count')

df_skills_count
# Out:
#       job_skills            job_title_short  skill_count
# 0         python             Data Scientist       113711
# 1            sql              Data Engineer       113130
# 2         python              Data Engineer       108022
# 3            sql               Data Analyst        92428
# 4            sql             Data Scientist        78982
# ...          ...                        ...          ...
# 2251       webex      Senior Data Scientist            1
# 2252  mattermost             Data Scientist            1
# 2253     clickup  Machine Learning Engineer            1
# 2254      heroku        Senior Data Analyst            1
# 2255    msaccess               Data Analyst            1
#
# [2256 rows x 3 columns]

# %%
job_titles = ['Data Scientist', 'Data Engineer', 'Data Analyst']

# %%
fig, ax = plt.subplots(3,1)

for i, job_title in enumerate(job_titles):
    df_plot = df_skills_count[df_skills_count['job_title_short'] == job_title].head(5)
    df_plot.plot(kind='barh', x='job_skills', y='skill_count', ax=ax[i], title=job_title)
    ax[i].invert_yaxis()
    ax[i].set_ylabel('')
    ax[i].legend().set_visible(False)
    ax[i].set_xlim(0, 120000)

fig.suptitle('Counts of Top Skills in Job Postings', fontsize=15)
fig.tight_layout()

# %% [markdown]
# ## Salary Distributions for DA in US

# %%
# plot histogram and boxplot for df_DA_US['salary_year_avg'] on same figure

# Only get data analyst jobs in the US
df_DA_US = df[(df['job_title_short'] == 'Data Analyst') & (df['job_country'] == 'United States')].copy()

# Drop NaN values from the column for plotting
df_DA_US = df_DA_US.dropna(subset=['salary_year_avg'])

fig, ax = plt.subplots(2, 1)
fig.tight_layout(h_pad=1)

df_DA_US['salary_year_avg'].plot(kind='hist', ax=ax[0], bins=30, edgecolor='black')
ax[0].set_title('Salary Distributions for Data Analyst in the US')
ax[0].set_xlabel('')
ax[0].set_ylabel('Frequency')
ax[0].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, pos: '${0:g}k'.format(x/1000)))
# lines
ax[0].axvline(df_DA_US['salary_year_avg'].median(), color='r', linestyle='--')
ax[0].axvline(df_DA_US['salary_year_avg'].quantile(0.25), color='y', linestyle='--')
ax[0].axvline(df_DA_US['salary_year_avg'].quantile(0.75), color='y', linestyle='--')
ax[0].legend(['', 'Median', 'Q1 & Q3'])


df_DA_US['salary_year_avg'].plot(kind='box', ax=ax[1], vert=False)
ax[1].set_yticklabels('')
ax[1].set_xlabel('Median Salary ($USD)')
ax[1].set_ylabel('')
ax[1].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, pos: '${0:g}k'.format(x/1000)))
# lines
ax[1].axvline(df_DA_US['salary_year_avg'].median(), color='r', linestyle='--')
ax[1].axvline(df_DA_US['salary_year_avg'].quantile(0.25), color='y', linestyle='--')
ax[1].axvline(df_DA_US['salary_year_avg'].quantile(0.75), color='y', linestyle='--')
plt.show()

# %% [markdown]
# ## Skill Pay Analysis

# %%
# Only get data analyst jobs in the US
df_DA_US = df[(df['job_title_short'] == 'Data Analyst') & (df['job_country'] == 'United States')].copy()

# Drop NaN values from the column for plotting
df_DA_US = df_DA_US.dropna(subset=['salary_year_avg'])

# %%
df_DA_US = df_DA_US.explode('job_skills')

# %%
df_DA_US_group = df_DA_US.groupby('job_skills')['salary_year_avg'].agg(['count', 'median'])
df_DA_US_group
# Out:
#             count     median
# job_skills
# airflow        44  116250.00
# airtable        5   90000.00
# alteryx       106  106281.25
# angular         8  107500.00
# ansible         1  159640.00
# ...           ...        ...
# wire            4   74250.00
# word          461   81194.75
# workfront       3   75000.00
# wrike           1   75000.00
# zoom           15   80740.00
#
# [170 rows x 2 columns]

# %%
df_DA_top_pay = df_DA_US_group.sort_values(by='median', ascending=False).head(10)
df_DA_top_pay
# Out:
#             count     median
# job_skills
# ansible         1  159640.00
# airflow        44  116250.00
# angular         8  107500.00
# alteryx       106  106281.25
# atlassian      10  104750.00
# asp.net         3   97500.00
# airtable        5   90000.00
# arch            3   84000.00
# assembly       16   80410.00
# asana          10   77500.00

# %%
df_DA_skills = df_DA_US_group.sort_values(by='count', ascending=False).head(10).sort_values(by='median', ascending=False)
df_DA_skills
# Out:
#             count    median
# job_skills
# python       1431  97500.00
# tableau      1364  92875.00
# r             893  92500.00
# sql server    286  92500.00
# sql          2508  91000.00
# sas           926  90000.00
# power bi      838  90000.00
# powerpoint    462  85000.00
# excel        1808  84392.00
# word          461  81194.75

# %%
fig, ax = plt.subplots(2, 1)

df_DA_top_pay[::-1].plot(kind='barh', y='median', ax=ax[0], legend=False)
ax[0].set_title('Top 10 Highest Paid Skills for Data Analysts')
ax[0].set_ylabel('')
ax[0].set_xlabel('')
ax[0].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'${int(x/1000)}K'))

df_DA_skills[::-1].plot(kind='barh', y='median', ax=ax[1], legend=False)
ax[1].set_title('Top 10 Most In-Demand Skills for Data Analysts')
ax[1].set_ylabel('')
ax[1].set_xlabel('Median Salary (USD)')
ax[1].set_xlim(ax[0].get_xlim())
ax[1].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'${int(x/1000)}K'))

plt.tight_layout()
