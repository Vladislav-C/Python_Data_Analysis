# %% [markdown]
# ## Pandas Index Management

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("../Data/data_jobs.csv")
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'], errors='coerce')

# %% [markdown]
# * You can get or set properties of the index, such as its name or data type.
# * It's helpful for maintaining metadata or ensuring index compatibility in operations.
# * `(index.name, index.dtype)`
#     * `index.name` - name of the index
#     * `index.dtype` - data type of the index

# %%
df.sample(3)
# Out:
#        job_title_short                           job_title  \
# 605576    Data Analyst                 Junior Data Analyst
# 187462   Data Engineer       Data Engineer Expérimenté H/F
# 82610    Data Engineer  Principal Associate, Data Engineer
#
#               job_location          job_via job_schedule_type  \
# 605576           Hong Kong  via Trabajo.org         Full-time
# 187462            Anywhere    via HelloWork         Full-time
# 82610   Fredericksburg, VA      via Monster         Full-time
#
#         job_work_from_home       search_location     job_posted_date  \
# 605576               False             Hong Kong 2023-08-10 09:39:40
# 187462                True                France 2023-05-05 15:36:32
# 82610                False  Texas, United States 2023-06-05 00:27:54
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 605576                   True                 False      Hong Kong
# ...

# %%
# Index ispection
df.index
# Out:
# RangeIndex(start=0, stop=785741, step=1)

# %%
df.index.dtype
# Out:
# dtype('int64')

# %%
df.index.name

# %% [markdown]
# It has no name..

# %%
df.index.name = 'job_index'
df.index.name
# Out:
# 'job_index'

# %%
df.sample(3)
# Out:
#                  job_title_short  \
# job_index
# 626620     Senior Data Scientist
# 444219            Data Scientist
# 477969             Data Engineer
#
#                                                    job_title  \
# job_index
# 626620          Senior Open-Source Data Scientist Consultant
# 444219                                  Head of Data Science
# 477969     Sr. Bioinformatics Data & Application Engineer...
#
#                job_location          job_via job_schedule_type  \
# job_index
# 626620           Reston, VA      via Ladders         Full-time
# 444219     Barcelona, Spain     via Jobijoba         Full-time
# 477969          Switzerland  via Recruit.net         Full-time
#
#            job_work_from_home search_location     job_posted_date  \
# job_index
# 626620                  False         Georgia 2023-08-11 12:40:10
# 444219                  False           Spain 2023-09-01 16:39:39
# 477969                  False     Switzerland 2023-01-04 00:05:56
#
# ...

# %% [markdown]
# ## reset_index()
#
# * `reset_index()`: Resets the DataFrame’s index to the default integer index. This is particularly useful after operations that alter the index, like sorting or filtering, to simplify further data manipulation.

# %%
df_usa = df[df['job_country'] == 'United States']

df_usa.head(5)
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 3                 Data Engineer
# 5                 Data Engineer
# 6          Senior Data Engineer
# 9                Data Scientist
#
#                                                    job_title     job_location  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...    Watertown, CT
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...  San Antonio, TX
# 5                                          GCP Data Engineer         Anywhere
# 6                          Senior Data Engineer  - GCP Cloud     Dearborn, MI
# 9                                          Data Scientist II         Anywhere
#
#                      job_via         job_schedule_type  job_work_from_home  \
# job_index
# 0            via Work Nearby                 Full-time               False
# 3          via Diversity.com                 Full-time               False
# ...

# %%
df_usa.index
# Out:
# Index([     0,      3,      5,      6,      9,     11,     13,     17,     26,
#            27,
#        ...
#        785625, 785626, 785641, 785648, 785651, 785673, 785685, 785692, 785703,
#        785705],
#       dtype='int64', name='job_index', length=206292)

# %%
# Make "indexes" correlate with the actual indexes
df_usa.reset_index(inplace=True)
df_usa.head()
# Out:
#    job_index       job_title_short  \
# 0          0  Senior Data Engineer
# 1          3         Data Engineer
# 2          5         Data Engineer
# 3          6  Senior Data Engineer
# 4          9        Data Scientist
#
#                                            job_title     job_location  \
# 0  Senior Clinical Data Engineer / Principal Clin...    Watertown, CT
# 1  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...  San Antonio, TX
# 2                                  GCP Data Engineer         Anywhere
# 3                  Senior Data Engineer  - GCP Cloud     Dearborn, MI
# 4                                  Data Scientist II         Anywhere
#
#              job_via         job_schedule_type  job_work_from_home  \
# 0    via Work Nearby                 Full-time               False
# 1  via Diversity.com                 Full-time               False
# 2   via ZipRecruiter  Contractor and Temp work                True
# ...

# %% [markdown]
# Technically we could `.drop()` the `job_index`.
#
# BUT, if we wanted to do some sort of merge operations in the future with our original DataFrame, this provides the unique `id` to do that.

# %%
median_pivot = df.pivot_table(values='salary_year_avg', index='job_title_short', aggfunc='median')
median_pivot
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   85000.0
# Cloud Engineer                     90000.0
# Data Analyst                       90000.0
# Data Engineer                     125000.0
# Data Scientist                    127500.0
# Machine Learning Engineer         106415.0
# Senior Data Analyst               111175.0
# Senior Data Engineer              147500.0
# Senior Data Scientist             155500.0
# Software Engineer                  99150.0

# %%
median_pivot.reset_index(inplace=True)
median_pivot
# Out:
#              job_title_short  salary_year_avg
# 0           Business Analyst          85000.0
# 1             Cloud Engineer          90000.0
# 2               Data Analyst          90000.0
# 3              Data Engineer         125000.0
# 4             Data Scientist         127500.0
# 5  Machine Learning Engineer         106415.0
# 6        Senior Data Analyst         111175.0
# 7       Senior Data Engineer         147500.0
# 8      Senior Data Scientist         155500.0
# 9          Software Engineer          99150.0

# %% [markdown]
# ## set_index()
#
# * `set_index()`: Sets one or more existing columns as the index of the DataFrame. This is useful for timeseries data or when you want to index by specific attributes.

# %%
df_usa.set_index('job_index', inplace=True)

df_usa.head()
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 3                 Data Engineer
# 5                 Data Engineer
# 6          Senior Data Engineer
# 9                Data Scientist
#
#                                                    job_title     job_location  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...    Watertown, CT
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...  San Antonio, TX
# 5                                          GCP Data Engineer         Anywhere
# 6                          Senior Data Engineer  - GCP Cloud     Dearborn, MI
# 9                                          Data Scientist II         Anywhere
#
#                      job_via         job_schedule_type  job_work_from_home  \
# job_index
# 0            via Work Nearby                 Full-time               False
# 3          via Diversity.com                 Full-time               False
# ...

# %%
median_pivot.set_index('job_title_short', inplace=True)
median_pivot
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   85000.0
# Cloud Engineer                     90000.0
# Data Analyst                       90000.0
# Data Engineer                     125000.0
# Data Scientist                    127500.0
# Machine Learning Engineer         106415.0
# Senior Data Analyst               111175.0
# Senior Data Engineer              147500.0
# Senior Data Scientist             155500.0
# Software Engineer                  99150.0

# %% [markdown]
# ## sort_index()
#
# * `sort_index()`: Sorts the DataFrame by the index (row labels), either ascending or descending. This helps in quickly organizing data by the index and is often used after `set_index()`.

# %%
median_pivot.sort_index(inplace=True)
median_pivot
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   85000.0
# Cloud Engineer                     90000.0
# Data Analyst                       90000.0
# Data Engineer                     125000.0
# Data Scientist                    127500.0
# Machine Learning Engineer         106415.0
# Senior Data Analyst               111175.0
# Senior Data Engineer              147500.0
# Senior Data Scientist             155500.0
# Software Engineer                  99150.0

# %% [markdown]
# ## Problems

# %%
pt = df.pivot_table(values='salary_year_avg', index='job_title_short', aggfunc=['median', 'min', 'max'])

pt
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  85000.0         16500.0        387460.0
# Cloud Engineer                    90000.0         42000.0        280000.0
# Data Analyst                      90000.0         25000.0        650000.0
# Data Engineer                    125000.0         15000.0        525000.0
# Data Scientist                   127500.0         27000.0        960000.0
# Machine Learning Engineer        106415.0         30000.0        325000.0
# Senior Data Analyst              111175.0         30000.0        425000.0
# Senior Data Engineer             147500.0         35000.0        425000.0
# Senior Data Scientist            155500.0         45000.0        890000.0
# Software Engineer                 99150.0         28000.0        375000.0

# %%
pt.sort_values(by=('median', 'salary_year_avg'), ascending=False)
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Senior Data Scientist            155500.0         45000.0        890000.0
# Senior Data Engineer             147500.0         35000.0        425000.0
# Data Scientist                   127500.0         27000.0        960000.0
# Data Engineer                    125000.0         15000.0        525000.0
# Senior Data Analyst              111175.0         30000.0        425000.0
# Machine Learning Engineer        106415.0         30000.0        325000.0
# Software Engineer                 99150.0         28000.0        375000.0
# Cloud Engineer                    90000.0         42000.0        280000.0
# Data Analyst                      90000.0         25000.0        650000.0
# Business Analyst                  85000.0         16500.0        387460.0

# %%
df_new = df.set_index('job_posted_date')
df_new.head()
# Out:
#                           job_title_short  \
# job_posted_date
# 2023-06-16 13:44:15  Senior Data Engineer
# 2023-01-14 13:18:07          Data Analyst
# 2023-10-10 13:14:55         Data Engineer
# 2023-07-04 13:01:41         Data Engineer
# 2023-08-07 14:29:36         Data Engineer
#
#                                                              job_title  \
# job_posted_date
# 2023-06-16 13:44:15  Senior Clinical Data Engineer / Principal Clin...
# 2023-01-14 13:18:07                                       Data Analyst
# 2023-10-10 13:14:55  Data Engineer/Scientist/Analyst, Mid or Senior...
# 2023-07-04 13:01:41  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 2023-08-07 14:29:36                             Data Engineer- Sr Jobs
#
#                                      job_location             job_via  \
# job_posted_date
# 2023-06-16 13:44:15                 Watertown, CT     via Work Nearby
# 2023-01-14 13:18:07  Guadalajara, Jalisco, Mexico    via BeBee México
# ...

# %%
df_new.reset_index(drop=True, inplace=True)

df_new.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location  job_no_degree_mention  \
# ...

# %%
pt_new = df.pivot_table(values='salary_year_avg', index='company_name', aggfunc='median')
pt_new.sort_index(inplace=True, ascending=False)
pt_new.head()
# Out:
#                                     salary_year_avg
# company_name
# ​Illinois State Board of Education          62536.0
# Технологическая компания                   280000.0
# ЛАНИТ                                      400000.0
# ztp                                         95000.0
# zooplus SE                                 161750.0

# %%
pt_new = df.pivot_table(values='salary_year_avg', index='job_title_short', aggfunc='median')
pt_new.reset_index(inplace=True)
pt_new.set_index('salary_year_avg', inplace=True)
pt_new.head()
# Out:
#                   job_title_short
# salary_year_avg
# 85000.0          Business Analyst
# 90000.0            Cloud Engineer
# 90000.0              Data Analyst
# 125000.0            Data Engineer
# 127500.0           Data Scientist
