# %% [markdown]
# # Pandas Accessing Data

# %%
import pandas as pd

df = pd.read_csv("../_Data/data_jobs.csv")
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'], errors='coerce')

# %%
df.loc[:, 'salary_rate':'salary_hour_avg'].dropna(subset='salary_rate')
# Out:
#        salary_rate  salary_year_avg  salary_hour_avg
# 28            year         109500.0              NaN
# 43            hour              NaN             97.5
# 51            hour              NaN             72.5
# 77            year         140000.0              NaN
# 92            year         120000.0              NaN
# ...            ...              ...              ...
# 785624        year         139216.0              NaN
# 785641        year         150000.0              NaN
# 785648        year         221875.0              NaN
# 785682        year         157500.0              NaN
# 785692        year         157500.0              NaN
#
# [33067 rows x 3 columns]

# %%
df[['job_title', 'job_location']].head()
# Out:
#                                            job_title  \
# 0  Senior Clinical Data Engineer / Principal Clin...
# 1                                       Data Analyst
# 2  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                             Data Engineer- Sr Jobs
#
#                    job_location
# 0                 Watertown, CT
# 1  Guadalajara, Jalisco, Mexico
# 2               Berlin, Germany
# 3               San Antonio, TX
# 4                Washington, DC

# %%
df.iloc[:5, [1, 2]]
# Out:
#                                            job_title  \
# 0  Senior Clinical Data Engineer / Principal Clin...
# 1                                       Data Analyst
# 2  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                             Data Engineer- Sr Jobs
#
#                    job_location
# 0                 Watertown, CT
# 1  Guadalajara, Jalisco, Mexico
# 2               Berlin, Germany
# 3               San Antonio, TX
# 4                Washington, DC

# %%
df.loc[5:10, 'job_title':'job_posted_date']
# Out:
#                                    job_title         job_location  \
# 5                          GCP Data Engineer             Anywhere
# 6          Senior Data Engineer  - GCP Cloud         Dearborn, MI
# 7                              Data Engineer             Anywhere
# 8   Technology & Operations Business Analyst  Copenhagen, Denmark
# 9                          Data Scientist II             Anywhere
# 10      Erfahrene*r Data Engineer*in (m/w/d)   Basel, Switzerland
#
#              job_via         job_schedule_type  job_work_from_home  \
# 5   via ZipRecruiter  Contractor and Temp work                True
# 6       via LinkedIn                 Full-time               False
# 7       via LinkedIn                 Full-time                True
# 8    via Trabajo.org                 Full-time               False
# 9   via ZipRecruiter                 Full-time                True
# 10      via LinkedIn                 Full-time               False
#
# ...

# %%
df_us = df[df['job_country'] == 'United States'].iloc[:15]
df_us[['job_title', 'salary_year_avg']]
# Out:
#                                             job_title  salary_year_avg
# 0   Senior Clinical Data Engineer / Principal Clin...              NaN
# 3   LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...              NaN
# 5                                   GCP Data Engineer              NaN
# 6                   Senior Data Engineer  - GCP Cloud              NaN
# 9                                   Data Scientist II              NaN
# 11                                      Data Engineer              NaN
# 13                               Senior Data Engineer              NaN
# 17                             Data Science Team Lead              NaN
# 26                                      Data Engineer              NaN
# 27  Principal Data Engineer (Lead), Knowledge Grap...              NaN
# 30     Senior Data Engineer (Work from home Eligible)              NaN
# 32   Sr. Data Scientist (NLP) - Full-time / Part-time              NaN
# ...

# %%
df_us = df[df['job_country'] == 'United States'].reset_index(drop=True).loc[:14, ['job_title', 'salary_year_avg']]
df_us
# Out:
#                                             job_title  salary_year_avg
# 0   Senior Clinical Data Engineer / Principal Clin...              NaN
# 1   LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...              NaN
# 2                                   GCP Data Engineer              NaN
# 3                   Senior Data Engineer  - GCP Cloud              NaN
# 4                                   Data Scientist II              NaN
# 5                                       Data Engineer              NaN
# 6                                Senior Data Engineer              NaN
# 7                              Data Science Team Lead              NaN
# 8                                       Data Engineer              NaN
# 9   Principal Data Engineer (Lead), Knowledge Grap...              NaN
# 10     Senior Data Engineer (Work from home Eligible)              NaN
# 11   Sr. Data Scientist (NLP) - Full-time / Part-time              NaN
# ...

# %%
start = pd.Timestamp('2023-05-01')

df[df['job_posted_date'] > start].iloc[:15][['job_title', 'job_location', 'job_posted_date']]
# Out:
#                                             job_title  \
# 0   Senior Clinical Data Engineer / Principal Clin...
# 2   Data Engineer/Scientist/Analyst, Mid or Senior...
# 3   LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                              Data Engineer- Sr Jobs
# 5                                   GCP Data Engineer
# 7                                       Data Engineer
# 8            Technology & Operations Business Analyst
# 11                                      Data Engineer
# 12        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 13                               Senior Data Engineer
# 14                                      Data Engineer
# 15                                      Data Engineer
# 16                                  Big Data Engineer
# 17                             Data Science Team Lead
# 18                                       Data Analyst
#
#                                        job_location     job_posted_date
# ...

# %%
df.loc[df['job_posted_date'] > '2023-05-01', ['job_title', 'job_location', 'job_posted_date']].head(15)
# Out:
#                                             job_title  \
# 0   Senior Clinical Data Engineer / Principal Clin...
# 2   Data Engineer/Scientist/Analyst, Mid or Senior...
# 3   LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                              Data Engineer- Sr Jobs
# 5                                   GCP Data Engineer
# 7                                       Data Engineer
# 8            Technology & Operations Business Analyst
# 11                                      Data Engineer
# 12        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 13                               Senior Data Engineer
# 14                                      Data Engineer
# 15                                      Data Engineer
# 16                                  Big Data Engineer
# 17                             Data Science Team Lead
# 18                                       Data Analyst
#
#                                        job_location     job_posted_date
# ...
