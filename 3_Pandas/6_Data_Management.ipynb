# %% [markdown]
# # Pandas Data Management

# %%
import pandas as pd

df = pd.read_csv("../_Data/data_jobs.csv")
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'], errors='coerce')

# %% [markdown]
# ## Sample
#
# * `sample()`: Random sample of items.
#
# Let's get a random sample of the data. You could get a sample with a fixed row number.

# %%
df.sample(5)
# Out:
#               job_title_short                                 job_title  \
# 495161      Software Engineer                           Python Engineer
# 159559  Senior Data Scientist                     Senior Data Scientist
# 31321       Software Engineer                    Certification Engineer
# 326450   Senior Data Engineer                      Senior Data Engineer
# 387490         Data Scientist  Machine Leaning and Data Science Analyst
#
#               job_location          job_via job_schedule_type  \
# 495161      Warsaw, Poland  via Trabajo.org         Full-time
# 159559            Anywhere        via hh.ru         Full-time
# 31321   Gothenburg, Sweden  via Trabajo.org         Full-time
# 326450       Paris, France  via Recruit.net         Full-time
# 387490       Cambridge, MA     via LinkedIn         Full-time
#
#         job_work_from_home          search_location     job_posted_date  \
# 495161               False                   Poland 2023-02-05 11:22:03
# 159559                True                   Russia 2023-04-04 08:37:49
# 31321                False                   Sweden 2023-04-23 13:10:10
# 326450               False                   France 2023-08-06 23:54:53
# 387490               False  New York, United States 2023-07-14 18:03:22
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 495161                   True                 False         Poland
# 159559                  False                 False         Russia
# 31321                    True                 False         Sweden
# 326450                   True                 False         France
# 387490                  False                 False  United States
#
#        salary_rate  salary_year_avg  salary_hour_avg           company_name  \
# 495161         NaN              NaN              NaN                 Kyriba
# 159559         NaN              NaN              NaN  Positive Technologies
# 31321          NaN              NaN              NaN  Integro Consulting AB
# 326450         NaN              NaN              NaN                   Dott
# 387490         NaN              NaN              NaN          Link Ventures
#
#                                                job_skills  \
# 495161                          ['python', 'word', 'git']
# 159559   ['python', 'pytorch', 'github', 'git', 'docker']
# 31321                                                 NaN
# 326450  ['python', 'sql', 'bigquery', 'airflow', 'spar...
# 387490                                            ['sql']
#
#                                           job_type_skills
# 495161  {'analyst_tools': ['word'], 'other': ['git'], ...
# 159559  {'libraries': ['pytorch'], 'other': ['github',...
# 31321                                                 NaN
# 326450  {'cloud': ['bigquery'], 'libraries': ['airflow...
# 387490                           {'programming': ['sql']}

# %%
df.sample(5, random_state=42)
# Out:
#               job_title_short  \
# 502901   Senior Data Engineer
# 406337  Senior Data Scientist
# 659951          Data Engineer
# 541593           Data Analyst
# 425158   Senior Data Engineer
#
#                                                 job_title  \
# 502901                               Senior Data Engineer
# 406337                          Senior Analytics Engineer
# 659951                                      Data Engineer
# 541593                                       Data Analyst
# 425158  Senior Data Engineer. Job in Amsterdam NBC4i Jobs
#
#                    job_location          job_via job_schedule_type  \
# 502901              St Paul, MN        via BeBee         Full-time
# 406337               London, UK     via LinkedIn         Full-time
# 659951  Newcastle upon Tyne, UK       via Indeed         Full-time
# 541593                    Malta  via Trabajo.org         Full-time
# 425158   Amsterdam, Netherlands   via NBC4i Jobs         Full-time
#
#         job_work_from_home         search_location     job_posted_date  \
# 502901               False  Florida, United States 2023-12-17 11:09:06
# 406337               False          United Kingdom 2023-10-06 16:09:56
# 659951               False          United Kingdom 2023-09-06 10:11:25
# 541593               False                   Malta 2023-02-14 21:14:18
# 425158               False             Netherlands 2023-06-19 16:34:30
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 502901                  False                 False   United States
# 406337                  False                 False  United Kingdom
# 659951                   True                 False  United Kingdom
# 541593                   True                 False           Malta
# 425158                   True                 False     Netherlands
#
#        salary_rate  salary_year_avg  salary_hour_avg            company_name  \
# 502901         NaN              NaN              NaN           ManpowerGroup
# 406337         NaN              NaN              NaN                 Harnham
# 659951         NaN              NaN              NaN             Morgan King
# 541593         NaN              NaN              NaN                 Konnekt
# 425158         NaN              NaN              NaN  Independent Recruiters
#
#                                                job_skills  \
# 502901                            ['sql', 'azure', 'git']
# 406337  ['sql', 'python', 'bigquery', 'snowflake', 'lo...
# 659951                                                NaN
# 541593                                           ['jira']
# 425158                                         ['python']
#
#                                           job_type_skills
# 502901  {'cloud': ['azure'], 'other': ['git'], 'progra...
# 406337  {'analyst_tools': ['looker'], 'cloud': ['bigqu...
# 659951                                                NaN
# 541593                                {'async': ['jira']}
# 425158                        {'programming': ['python']}

# %% [markdown]
# Or you can randomly select a fraction of the data (e.g., 10% of the rows), with or without replacement.

# %%
df.sample(frac=0.1, replace=False)
# Out:
#              job_title_short  \
# 318673         Data Engineer
# 412931         Data Engineer
# 210073  Senior Data Engineer
# 408854          Data Analyst
# 635319      Business Analyst
# ...                      ...
# 298146         Data Engineer
# 89327         Data Scientist
# 93451          Data Engineer
# 694622  Senior Data Engineer
# 229382          Data Analyst
#
#                                                 job_title  \
# 318673                                      Data Engineer
# 412931                                      Data Engineer
# 210073                         Senior Data Engineer MLOps
# 408854  Staff Business Data Analyst (Anaplan Model Bui...
# 635319                              Sr. Financial Analyst
# ...                                                   ...
# 298146            Image and Data Analysis Engineer Intern
# 89327                         Data Scientist - Consultant
# 93451                                   Sr. Data Engineer
# 694622               👨💻  Senior/Lead Python Data Engineer
# 229382                            Data analyst junior H/F
#
#                         job_location            job_via job_schedule_type  \
# 318673             Piaseczno, Poland         via Adzuna         Full-time
# 412931                      Anywhere       via LinkedIn         Full-time
# 210073  Dubai - United Arab Emirates         via Indeed         Full-time
# 408854                     Plano, TX       via LinkedIn         Full-time
# 635319   Vélizy-Villacoublay, France          via BeBee         Full-time
# ...                              ...                ...               ...
# 298146               Santa Clara, CA          via Nexxt        Internship
# 89327        Bailey's Crossroads, VA  via CareerBuilder         Full-time
# 93451       KENNEDY SPACE CENTER, FL  via CareerBuilder         Full-time
# 694622                      Anywhere       via LinkedIn         Full-time
# 229382                 Paris, France         via Indeed               NaN
#
#         job_work_from_home            search_location     job_posted_date  \
# 318673               False                     Poland 2023-09-05 17:22:40
# 412931                True    Illinois, United States 2023-09-01 16:29:36
# 210073               False       United Arab Emirates 2023-01-05 22:49:37
# 408854               False       Texas, United States 2023-04-12 16:01:17
# 635319               False                     France 2023-12-13 12:19:12
# ...                    ...                        ...                 ...
# 298146               False  California, United States 2023-02-24 17:01:05
# 89327                False    New York, United States 2023-02-22 00:23:56
# 93451                False       Texas, United States 2023-05-27 00:08:19
# 694622                True                     Poland 2023-05-27 10:15:43
# 229382               False                     France 2023-08-07 08:17:20
#
#         job_no_degree_mention  job_health_insurance           job_country  \
# 318673                  False                 False                Poland
# 412931                   True                 False         United States
# 210073                  False                 False  United Arab Emirates
# 408854                  False                 False         United States
# 635319                  False                 False                France
# ...                       ...                   ...                   ...
# 298146                  False                 False         United States
# 89327                   False                  True         United States
# 93451                   False                 False         United States
# 694622                  False                 False                Poland
# 229382                  False                 False                France
#
#        salary_rate  salary_year_avg  salary_hour_avg        company_name  \
# 318673         NaN              NaN              NaN    Bayer Sp. z o.o.
# 412931        year         115000.0              NaN                 CRG
# 210073         NaN              NaN              NaN            XA Group
# 408854         NaN              NaN              NaN              Intuit
# 635319         NaN              NaN              NaN   Dassault Systèmes
# ...            ...              ...              ...                 ...
# 298146         NaN              NaN              NaN   Applied Materials
# 89327          NaN              NaN              NaN          Guidehouse
# 93451          NaN              NaN              NaN      Latitude, Inc.
# 694622         NaN              NaN              NaN               juucy
# 229382         NaN              NaN              NaN  SIACI SAINT HONORE
#
#                                                job_skills  \
# 318673          ['python', 'aws', 'graphql', 'terraform']
# 412931  ['sql', 'sql server', 'azure', 'aws', 'databri...
# 210073  ['python', 'c', 'c++', 'azure', 'tensorflow', ...
# 408854                                  ['excel', 'flow']
# 635319                                   ['sql', 'excel']
# ...                                                   ...
# 298146                                         ['python']
# 89327                              ['python', 'r', 'sql']
# 93451   ['python', 'sql', 'r', 'snowflake', 'tableau',...
# 694622              ['python', 'sql', 'kafka', 'airflow']
# 229382      ['python', 'pandas', 'numpy', 'scikit-learn']
#
#                                           job_type_skills
# 318673  {'cloud': ['aws'], 'libraries': ['graphql'], '...
# 412931  {'analyst_tools': ['ssis', 'tableau', 'power b...
# 210073  {'cloud': ['azure'], 'libraries': ['tensorflow...
# 408854    {'analyst_tools': ['excel'], 'other': ['flow']}
# 635319  {'analyst_tools': ['excel'], 'programming': ['...
# ...                                                   ...
# 298146                        {'programming': ['python']}
# 89327             {'programming': ['python', 'r', 'sql']}
# 93451   {'analyst_tools': ['tableau'], 'cloud': ['snow...
# 694622  {'libraries': ['kafka', 'airflow'], 'programmi...
# 229382  {'libraries': ['pandas', 'numpy', 'scikit-lear...
#
# [78574 rows x 17 columns]
